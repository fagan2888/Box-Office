# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import json
import ast
import re
import math
import pandas_datareader as pdr
import pandas.io.sql as pd_sql
import sqlite3 as sql
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns
# %matplotlib notebook

# %%
con = sql.connect(r'c:\users\rebecca\.spyder-py3\movies.db') 

movies = pd_sql.read_sql('select * from finalMovies_20180804', con, index_col='index')

# %%
movies.head(5)
# Out:
#        movieId  tmdbId  Rating_MovieLens                   Awards  \
# index
# 0          NaN     NaN               NaN                     None
# 1          NaN     NaN               NaN                     None
# 2          NaN     NaN               NaN                     None
# 3          NaN     NaN               NaN                     None
# 4          NaN     NaN               NaN  4 wins & 4 nominations.
#
#                                                     Plot  Rated    Year  \
# index
# 0      A small group of former classmates organize an...      R  2018.0
# 1      The movie is a remake of the 1972 blaxploitati...      R  2018.0
# 2      Bob Parr (Mr. Incredible) is left to care for ...     PG  2018.0
# 3        The story of crime boss John Gotti and his son.      R  2018.0
# 4      An exploration of the life, lessons, and legac...  PG-13  2018.0
#
#        imdbVotes  Rating_RT                       Name          ...           \
# ...

# %%
movies.describe()
# Out:
#             movieId        tmdbId  Rating_MovieLens         Year  \
# count  5.283000e+03  5.283000e+03       5274.000000  6136.000000
# mean   7.005243e+04  9.066482e+04         43.727615  2007.608214
# std    6.535724e+04  1.166843e+05       2946.599321     6.390500
# min    1.000000e+00  5.000000e+00          0.500000  1995.000000
# 25%    6.334500e+03  1.054950e+04          2.833333  2003.000000
# 50%    6.568200e+04  2.997900e+04          3.194012  2008.000000
# 75%    1.104560e+05  1.367960e+05          3.501752  2013.000000
# max    2.120338e+06  2.023923e+06     213992.000000  2018.000000
#
#           imdbVotes    Rating_RT       Revenue       Length        Budget  \
# count  5.638000e+03  5394.000000  6.136000e+03  5670.000000  4.662000e+03
# mean   6.663158e+04    54.034483  6.859142e+07   103.320473  3.263795e+07
# std    1.271320e+05    27.880449  1.585480e+08    17.218867  4.137595e+07
# min    6.000000e+00     0.000000  0.000000e+00     4.000000  1.000000e+00
# ...

# %%
test = movies[pd.notna(movies['Profit_Bucket'])]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(test['Revenue'], bins=30)
#plt.title('Age distribution')
#plt.xlabel('Age')
#plt.ylabel('Count of Passengers')
plt.show()
#test['Profit_Bucket'].value_counts()

# %%
g = sns.jointplot("Revenue_Real", "Won_Major", test)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
ax = sns.violinplot(x=test["Profit_Real"], y=test['Season'],scale="width")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = sns.violinplot(x=test["Revenue_Real"], y=test["Season"], hue=test['Genre_Drama'],cut=0, 
                    palette="Set2", split=True,scale="count")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = sns.stripplot(x=test["Season"], y=test["Revenue_Real"], hue=test["Rated_category"],  jitter=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#data = movies[['Rating_RT', 'Rating_IMDB', 'Rating_Metacritic', 'imdbVotes', \
#               'Length', 'TMDB_popularity','Revenue_Real', 'Budget_Real', \
#               'Profit_Real', 'Revenue_Actor_Real', 'Revenue_Director_Real', \
#               'Revenue_Writer_Real', 'Revenue_Producer_Real']]

data = movies[['Rating_IMDB',  'imdbVotes', \
               'Length', 'Revenue_Real', 'Budget_Real', \
               'Profit_Real', 'Season']]


scatter_matrix(data, figsize=(10,10))
plt.show()

# %%
#movies['imdbVotes'] = (movies['imdbVotes']).astype(int)
sns.pairplot(x_vars=["Profit_Real"], y_vars=["Length"], data=movies,  size=10, kind='reg')
# Out:
# C:\Users\Rebecca\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
pd.isnull(movies['Season']).count()
# Out:
# 6136

# %%
movies['Rated_category'].unique()
# Out:
# array(['R', 'PG', 'PG-13', 'Other', 'G'], dtype=object)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
axs[0].bar(movies['Season'], movies['Revenue_Real'])
axs[1].scatter(movies['Season'], movies['Revenue_Real'])
#axs[2].plot(movies['Season'], movies['Revenue_Real'])

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
axs[0].bar(movies['Rated_category'], movies['Revenue_Real'])
axs[1].scatter(movies['Rated_category'], movies['Revenue_Real'])

# %%
test = movies[pd.notna(movies['Profit_Bucket'])]
#test = test[test['imdbVotes']>0]
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
axs[0].bar(test['Profit_Bucket'], test['Revenue_Director_Real'])
axs[1].scatter(test['Profit_Bucket'], test['Revenue_Director_Real'])

# %% [markdown]
# ## ---------------------------------------
# ## Regression Models
# ## ---------------------------------------

# %%
import statsmodels.api as sm
test = movies[(movies['Revenue_Real']>0)&(movies['Budget_Real']>0)&(movies['Rating_RT']>=0) & movies['imdbVotes']>0]
model = sm.OLS(test['Revenue_Real'], test[['Budget_Real', 'Rating_RT','imdbVotes', 'Summer', 'Winter', 'Genre_Drama',
 'Genre_Comedy', 'Rated_G_PG', 'Rated_R',
'Comp_DreamWorks',
 'Comp_Fox',
 'Comp_Lionsgate',
 'Comp_MGM',
 'Comp_Miramax',
 'Comp_Paramount',
 'Comp_Sony',
 'Comp_Universal',
 'Comp_WarnerBros', 
 'Comp_Other']])
#model = sm.OLS(test['Revenue_Real'], test[['Budget_Real', 'imdbVotes']])

# %%
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Revenue_Real   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     651.9
# Date:                Mon, 06 Aug 2018   Prob (F-statistic):               0.00
# Time:                        18:40:02   Log-Likelihood:                -80136.
# No. Observations:                4000   AIC:                         1.603e+05
# Df Residuals:                    3981   BIC:                         1.604e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Budget_Real         2.2207      0.048     46.516      0.000       2.127       2.314
# ...

# %%
import statsmodels.api as sm
test = movies[(movies['Revenue_Real']>0)&movies['Budget_Real']>0]

test2 = test[['Revenue_Real', 'Budget_Real', 'Revenue_Actor_Real', 'Revenue_Director_Real']]

test2['Revenue_Actor_Real']=test2['Revenue_Actor_Real'].apply(lambda x: 0 if pd.isnull(x) else x)
model = sm.OLS(test2['Revenue_Real'], test2[['Revenue_Actor_Real']])#', 'Rating_RT','imdbVotes', 'Summer', 'Winter', 'Genre_Drama',
# 'Genre_Comedy', 'Rated_G_PG', 'Rated_R',
#'Comp_DreamWorks',
# 'Comp_Fox',
# 'Comp_Lionsgate',
# 'Comp_MGM',
# 'Comp_Miramax',
## 'Comp_Paramount',
# 'Comp_Sony',
# 'Comp_Universal',
# 'Comp_WarnerBros', 
# 'Comp_Other']])
#test.head(15)
# Out:
# C:\Users\Rebecca\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Revenue_Real   R-squared:                       0.266
# Model:                            OLS   Adj. R-squared:                  0.266
# Method:                 Least Squares   F-statistic:                     1692.
# Date:                Mon, 06 Aug 2018   Prob (F-statistic):          8.22e-316
# Time:                        18:48:48   Log-Likelihood:                -95754.
# No. Observations:                4661   AIC:                         1.915e+05
# Df Residuals:                    4660   BIC:                         1.915e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Revenue_Actor_Real     0.0289      0.001     41.134      0.000       0.028       0.030
# ...

# %% [markdown]
# ## ---------------------------------------
# ## Classification Models
# ## ---------------------------------------

# %% [markdown]
# RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import cross_validation
from sklearn.cross_validation import train_test_split
#test2 = test[pd.notna(test['Revenue_Actor_Real'])]
test = movies[(movies['Revenue_Real']>0)&movies['Budget_Real']>0]

test2['Profit_Bucket_Binary']=np.where(test2['Profit_Bucket']=='<1x', 0, np.where(test2['Profit_Bucket']=='[1-2x)', \
    0, np.where(test2['Profit_Bucket']=='[2-3x)', 1, np.where(test2['Profit_Bucket']=='[3-4x)', \
                       1, np.where(test2['Profit_Bucket']=='[4-5x)', 1, np.where(test2['Profit_Bucket']=='>=5x', 1, ''))))))
test2['Revenue_Actor_Real']=movies['Revenue_Actor_Real'].apply(lambda x: 0 if pd.isnull(x) else x)
test2['Revenue_Director_Real']=movies['Revenue_Director_Real'].apply(lambda x: 0 if pd.isnull(x) else x)

# %%
test2[['Profit_Bucket', 'Profit_Bucket_Binary']].head(15)
# Out:
#       Profit_Bucket Profit_Bucket_Binary
# index
# 0            [2-3x)                    1
# 1            [1-2x)                    0
# 2            [4-5x)                    1
# 3               <1x                    0
# 5            [3-4x)                    1
# 7               <1x                    0
# 8              >=5x                    1
# 9            [1-2x)                    0
# 10             >=5x                    1
# 11           [3-4x)                    1
# 13              <1x                    0
# 14           [1-2x)                    0
# 15              <1x                    0
# 17           [1-2x)                    0
# 18             >=5x                    1

# %%
###Try doing just profit bucket <2, >2
###DISCUSS WHEHER IMDB VOTES OR AWARDS ARE APPROPRIATE VARIABLES. 
###We won't have those numbers before a movie opens, but potentially during a movie's run.
X = test2[["Budget_Real", "Holiday", "Summer", "Spring", "Fall", "Winter",'Genre_Drama',
 'Genre_Comedy',
 'Genre_Action_Adventure',
 'Genre_Thriller_Horror',
 'Genre_Romance',
 'Genre_Crime_Mystery',
 'Genre_Animation',
 'Genre_Scifi',
 'Genre_Documentary',
 'Genre_Other',
 'Rated_G_PG',
 'Rated_PG-13',
 'Rated_R',
 'Rated_Other',  'Rated_G_PG',
 'Rated_PG-13',
 'Rated_R',
 'Rated_Other','Comp_Disney',
 'Comp_DreamWorks',
 'Comp_Fox',
 'Comp_Lionsgate',
 'Comp_MGM',
 'Comp_Miramax',
 'Comp_Paramount',
 'Comp_Sony',
 'Comp_Universal',
 'Comp_WarnerBros',
 'Comp_Other',  'Revenue_Actor_Real','Revenue_Director_Real',
'Nominated_Major', 'Nominated_Minor', 
           'Won_Major', 'Won_Minor'


]]
#y = test2["Profit_Bucket"]
y = test2["Profit_Bucket_Binary"]

# %%
rf = RandomForestClassifier(n_estimators=50, oob_score=True) 

# Next split up the data with the 'train test split' method in the Cross Validation module
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# ...and then run the 'fit' method to build a forest of trees
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=1,
#             oob_score=True, random_state=None, verbose=0, warm_start=False)

# %%
rf.score(X_test, y_test)
# Out:
# 0.7337662337662337

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
kernels = ['linear', 'poly', 'rbf']

splits     = cross_validation.train_test_split(X,y, test_size=0.2)
X_train, X_test, y_train, y_test = splits

for kernel in kernels:
    if kernel != 'poly':
        model      = SVC(kernel=kernel)
    else:
        model      = SVC(kernel=kernel, degree=3)

model.fit(X_train, y_train)
model.score(X_test, y_test)
#expected   = y_test
#predicted  = model.predict(X_test)

#SVC_report = classification_report(expected, predicted)
# Out:
# 0.5324675324675324

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=1)

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X,y,test_size = 0.2)
log_reg = lr.fit(X_train, y_train)
log_reg.score(X_test, y_test)
# Out:
# 0.5532467532467532

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()
features = test2[["Budget_Real", "Holiday", "Summer", "Spring", "Fall", "Winter",'Genre_Drama',
 'Genre_Comedy',
 'Genre_Action_Adventure',
 'Genre_Thriller_Horror',
 'Genre_Romance',
 'Genre_Crime_Mystery',
 'Genre_Animation',
 'Genre_Scifi',
 'Genre_Documentary',
 'Genre_Other',
 'Rated_G_PG',
 'Rated_PG-13',
 'Rated_R',
 'Rated_Other',  'Rated_G_PG',
 'Rated_PG-13',
 'Rated_R',
 'Rated_Other','Comp_Disney',
 'Comp_DreamWorks',
 'Comp_Fox',
 'Comp_Lionsgate',
 'Comp_MGM',
 'Comp_Miramax',
 'Comp_Paramount',
 'Comp_Sony',
 'Comp_Universal',
 'Comp_WarnerBros',
 'Comp_Other',  'Revenue_Actor_Real', 'Revenue_Director_Real',
'Nominated_Major', 'Nominated_Minor', 
           'Won_Major', 'Won_Minor'
]]
labels = test2["Profit_Bucket_Binary"]

# %%
model.fit(features, labels)
model.feature_importances_
# Out:
# array([0.1782621 , 0.00487299, 0.00276615, 0.00465495, 0.01512349,
#        0.01267729, 0.04212924, 0.04027306, 0.00622749, 0.01278128,
#        0.00279366, 0.00623791, 0.        , 0.00890187, 0.01009778,
#        0.02553111, 0.00776084, 0.00724243, 0.01212517, 0.00983862,
#        0.00832662, 0.0115793 , 0.01132705, 0.01641229, 0.01882295,
#        0.        , 0.02760942, 0.01634307, 0.        , 0.00956139,
#        0.01003166, 0.0170755 , 0.02203931, 0.00241768, 0.01387344,
#        0.09424103, 0.07271808, 0.00791518, 0.15144968, 0.01911698,
#        0.05884194])

# %%
# %matplotlib notebook
from yellowbrick.features import FeatureImportances

oz=FeatureImportances(GradientBoostingClassifier())
oz.fit(features, labels)
oz.poof()
# Out:
# <img src="data:image/png;base64,..." width="893.6">

# %%
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

#model = Lasso()
model = Lasso(alpha=0.1)
results=model.fit(features, labels)
print(list(zip(features, model.coef_.tolist())))
model.score(features, labels)
# Out:
# [('Budget_Real', 9.461968318480477e-10), ('Holiday', -0.0), ('Summer', 0.0), ('Spring', 0.0), ('Fall', -0.0), ('Winter', 0.0), ('Genre_Drama', -0.0), ('Genre_Comedy', 0.0), ('Genre_Action_Adventure', -0.0), ('Genre_Thriller_Horror', 0.0), ('Genre_Romance', 0.0), ('Genre_Crime_Mystery', -0.0), ('Genre_Animation', 0.0), ('Genre_Scifi', -0.0), ('Genre_Documentary', 0.0), ('Genre_Other', -0.0), ('Rated_G_PG', 0.0), ('Rated_PG-13', 0.0), ('Rated_R', -0.0), ('Rated_Other', -0.0), ('Rated_G_PG', 0.0), ('Rated_PG-13', 0.0), ('Rated_R', -0.0), ('Rated_Other', -0.0), ('Comp_Disney', 0.0), ('Comp_DreamWorks', 0.0), ('Comp_Fox', 0.0), ('Comp_Lionsgate', 0.0), ('Comp_MGM', -0.0), ('Comp_Miramax', -0.0), ('Comp_Paramount', 0.0), ('Comp_Sony', 0.0), ('Comp_Universal', 0.0), ('Comp_WarnerBros', -0.0), ('Comp_Other', -0.0), ('Revenue_Actor_Real', 4.400871694319105e-12), ('Revenue_Director_Real', 4.0098363207297556e-11), ('Nominated_Major', 0.0), ('Nominated_Minor', 0.00426130133520551), ('Won_Major',
# ...

# %%
#model = Ridge()
model = Ridge(alpha=0.001)
model.fit(features, labels)
print(list(zip(features, model.coef_.tolist())))
model.score(features, labels)
# Out:
# [('Budget_Real', -2.009530625999722e-10), ('Holiday', -0.010465402935517731), ('Summer', 0.018270779774239496), ('Spring', 0.011523258902674093), ('Fall', -0.058565690002006496), ('Winter', 0.039237054202469875), ('Genre_Drama', -0.15914870763499994), ('Genre_Comedy', 0.02578039477407728), ('Genre_Action_Adventure', -0.05261679645495619), ('Genre_Thriller_Horror', 0.07242459351748638), ('Genre_Romance', 0.029392075306707906), ('Genre_Crime_Mystery', -0.017523486404469744), ('Genre_Animation', 0.04197468495411059), ('Genre_Scifi', -0.06876784804594556), ('Genre_Documentary', 0.18786878744937935), ('Genre_Other', -0.07291571834141539), ('Rated_G_PG', 0.040146617535045725), ('Rated_PG-13', 0.036038640073245476), ('Rated_R', -0.014052500125424427), ('Rated_Other', -0.0621327578158438), ('Rated_G_PG', 0.040146617534774755), ('Rated_PG-13', 0.0360386400770837), ('Rated_R', -0.014052500126480271), ('Rated_Other', -0.06213275781584386), ('Comp_Disney', 0.2613410487885839), ('Comp_DreamWorks'
# ...

# %%
#model = ElasticNet()
model = ElasticNet(l1_ratio = 0.00001)
model.fit(features, labels)
print(list(zip(features, model.coef_.tolist())))
model.score(features, labels)
# Out:
# [('Budget_Real', 7.194171587721204e-10), ('Holiday', -0.0031312941763716987), ('Summer', 0.005610392574475909), ('Spring', 0.001757696996683343), ('Fall', -0.011163212349111622), ('Winter', 0.006916416854322995), ('Genre_Drama', -0.031999440972746124), ('Genre_Comedy', 0.015194560478806945), ('Genre_Action_Adventure', -0.0030040531063833128), ('Genre_Thriller_Horror', 0.005084447741212109), ('Genre_Romance', 0.0035873911206262465), ('Genre_Crime_Mystery', -0.0018964906853762595), ('Genre_Animation', 0.004232673715946548), ('Genre_Scifi', -0.002732316011554654), ('Genre_Documentary', 0.003210444005043027), ('Genre_Other', -0.009888875080076803), ('Rated_G_PG', 0.007684429691103527), ('Rated_PG-13', 0.009780683673600288), ('Rated_R', -0.01083929259354958), ('Rated_Other', -0.006625820771154088), ('Rated_G_PG', 0.007684429691103468), ('Rated_PG-13', 0.009780683673600084), ('Rated_R', -0.010839292593549278), ('Rated_Other', -0.0066258207711541025), ('Comp_Disney', 0.006864033645248506), 
# ...
